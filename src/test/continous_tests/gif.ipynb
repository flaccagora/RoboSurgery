# %%
from moviepy import VideoFileClip, concatenate_videoclips
import os

def combine_videos_to_gif(video_paths, output_gif_path, resize_factor=0.5, fps=10, max_duration_per_video=None):
    """
    Combine multiple videos into a single GIF
    
    Parameters:
    - video_paths: List of paths to the source video files
    - output_gif_path: Path where the output GIF will be saved
    - resize_factor: Resize the GIF (0.5 means half the original size)
    - fps: Frames per second in the output GIF
    - max_duration_per_video: Maximum duration to use from each video (in seconds)
    """
    clips = []
    
    for video_path in video_paths:
        # Load the video file
        video = VideoFileClip(video_path)
        
        # Limit duration if specified
        if max_duration_per_video is not None and video.duration > max_duration_per_video:
            video = video.subclip(0, max_duration_per_video)
        
        # Resize video
        # if resize_factor != 1:
        #     video = video.resize(resize_factor)
        
        clips.append(video)
    
    # Concatenate all clips
    final_clip = concatenate_videoclips(clips)
    
    # Write the GIF
    final_clip.write_gif(output_gif_path, fps=fps)
    
    # Close all clips to release resources
    final_clip.close()
    for clip in clips:
        clip.close()
    
    print(f"Combined GIF created at: {output_gif_path}")

# Example usage
if __name__ == "__main__":
    # List of your video files
    # video_files = [
    #     "videos/pomdp_gridworld_episode_1.mp4",
    #     "videos/pomdp_gridworld_episode_2.mp4",
    #     "videos/pomdp_gridworld_episode_3.mp4"
    # ]
    # list all files in the videos folder
    video_files = []
    for file in os.listdir("videos"):
        if file.endswith(".mp4"):
            video_files.append(os.path.join("videos", file))


    combine_videos_to_gif(
        video_paths=video_files,
        output_gif_path="gifs/combined_episodes.gif",
        resize_factor=0.4,  # 40% of original size
        fps=10,
        max_duration_per_video=5  # Take only first 5 seconds from each video
    )
# Out:
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2614, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.97, 'bitrate': 2622, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2614, 'video_fps': 30.0, 'video_duration': 0.97, 'video_n_frames': 29}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201039_episode_3_20250307_201052.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2532, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.1, 'bitrate': 2540, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2532, 'video_fps': 30.0, 'video_duration': 1.1, 'video_n_frames': 33}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201054_episode_1_20250307_201057.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2604, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.37, 'bitrate': 2624, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2604, 'video_fps': 30.0, 'video_duration': 0.37, 'video_n_frames': 11}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201115_episode_1_20250307_201116.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2466, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.23, 'bitrate': 2472, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2466, 'video_fps': 30.0, 'video_duration': 1.23, 'video_n_frames': 36}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_bello_20250307_201421_episode_1_20250307_201425.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2598, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.57, 'bitrate': 2604, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2598, 'video_fps': 30.0, 'video_duration': 1.57, 'video_n_frames': 47}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_bello_20250307_201039_episode_2_20250307_201049.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 1742, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.77, 'bitrate': 1747, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 1742, 'video_fps': 30.0, 'video_duration': 1.77, 'video_n_frames': 53}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201321_episode_1_20250307_201326.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 1878, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.4, 'bitrate': 1884, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 1878, 'video_fps': 30.0, 'video_duration': 1.4, 'video_n_frames': 42}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_bello_20250307_201039_episode_1_20250307_201043.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2024, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.67, 'bitrate': 2029, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2024, 'video_fps': 30.0, 'video_duration': 1.67, 'video_n_frames': 50}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_bello_20250307_201351_episode_1_20250307_201356.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 1952, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.7, 'bitrate': 1957, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 1952, 'video_fps': 30.0, 'video_duration': 1.7, 'video_n_frames': 51}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_bello_20250307_201011_episode_1_20250307_201017.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 3177, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.83, 'bitrate': 3186, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 3177, 'video_fps': 30.0, 'video_duration': 0.83, 'video_n_frames': 24}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_200941_episode_1_20250307_200943.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2756, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.43, 'bitrate': 2762, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2756, 'video_fps': 30.0, 'video_duration': 1.43, 'video_n_frames': 42}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201000_episode_1_20250307_201005.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 3432, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.47, 'bitrate': 3448, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 3432, 'video_fps': 30.0, 'video_duration': 0.47, 'video_n_frames': 14}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_200847_episode_1_20250307_200849.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 1924, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.7, 'bitrate': 1935, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 1924, 'video_fps': 30.0, 'video_duration': 0.7, 'video_n_frames': 21}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_200239_episode_1_20250307_200241.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2129, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.07, 'bitrate': 2136, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2129, 'video_fps': 30.0, 'video_duration': 1.07, 'video_n_frames': 32}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201337_episode_1_20250307_201341.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2154, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.67, 'bitrate': 2159, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2154, 'video_fps': 30.0, 'video_duration': 1.67, 'video_n_frames': 50}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_bello_20250307_201452_episode_1_20250307_201458.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2390, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.77, 'bitrate': 2401, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2390, 'video_fps': 30.0, 'video_duration': 0.77, 'video_n_frames': 23}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201416_episode_1_20250307_201419.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 3066, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.83, 'bitrate': 3075, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 3066, 'video_fps': 30.0, 'video_duration': 0.83, 'video_n_frames': 24}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_200858_episode_1_20250307_200900.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 1978, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.47, 'bitrate': 1984, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 1978, 'video_fps': 30.0, 'video_duration': 1.47, 'video_n_frames': 44}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201452_episode_2_20250307_201504.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2015, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 1.5, 'bitrate': 2020, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2015, 'video_fps': 30.0, 'video_duration': 1.5, 'video_n_frames': 45}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_201029_episode_1_20250307_201034.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# {'video_found': True, 'audio_found': False, 'metadata': {'major_brand': 'isom', 'minor_version': '512', 'compatible_brands': 'isomiso2mp41', 'encoder': 'Lavf59.27.100'}, 'inputs': [{'streams': [{'input_number': 0, 'stream_number': 0, 'stream_type': 'video', 'language': None, 'default': True, 'size': [1000, 1000], 'bitrate': 2681, 'fps': 30.0, 'codec_name': 'mpeg4', 'profile': '(Simple Profile)', 'metadata': {'Metadata': '', 'handler_name': 'VideoHandler', 'vendor_id': '[0][0][0][0]'}}], 'input_number': 0}], 'duration': 0.6, 'bitrate': 2694, 'start': 0.0, 'default_video_input_number': 0, 'default_video_stream_number': 0, 'video_codec_name': 'mpeg4', 'video_profile': '(Simple Profile)', 'video_size': [1000, 1000], 'video_bitrate': 2681, 'video_fps': 30.0, 'video_duration': 0.6, 'video_n_frames': 18}
# /home/flaccagora/.miniconda3/envs/RoboTorch/lib/python3.11/site-packages/imageio_ffmpeg/binaries/ffmpeg-linux-x86_64-v7.0.2 -i videos/pomdp_gridworld_20250307_200829_episode_1_20250307_200830.mp4 -loglevel error -f image2pipe -vf scale=1000:1000 -sws_flags bicubic -pix_fmt rgb24 -vcodec rawvideo -
# MoviePy - Building file gifs/combined_episodes.gif with imageio.
# Combined GIF created at: gifs/combined_episodes.gif
